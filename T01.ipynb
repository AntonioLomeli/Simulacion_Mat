# %% [markdown]
# # <span style="color:blue"> Mi Presentación</span>
# ***
# ***Antonio Lomelí Ureña***

# %% [markdown]
# <span style="font-family:Comic Sans MS">Soy estudiante de tercer semestre de ingeniería financiera, tengo 19 años y soy de Tepic. Me gusta que me digan <em>Antonio</em> y el semestre pasado tomé la clase de algoritmos y programación que no me gustó mucho.<br><br>Un tema de mi carrera que me llama la atención es el de análisis de datos.</span>
#
# #### Análisis de Datos
# ***
# ![image.png](attachment:image.png)

# %% [markdown]
# No he llevado la materia, pero he hecho un poco de investigación por mi cuenta y se trata de:
#
# - Recomendar acciones para resolver un problema específico
# - Analizar datos para tomar mejores decisiones
# - Seguir una serie de pasos para hacerlo de la mejor manera
#
# Los ***pasos*** de los que hablo son las etapas del análisis de datos y son cuatro, en orden:
#
# 1. Definir el problema
# 2. Dividir el problema en partes, para saber qué información buscar
# 3. Evaluar, los datos que recolectamos y a partir del análisis que se hace
# 4. Decidir/Concluir, para dar recomendaciones
#
# Para analizar los datos se usan herramientas de estadística, y se necesitan **fórmulas**, por ejemplo para hacer una distribución de frecuencias, la ecuación $ w=n/k $ nos da el ancho de clase de esa distribución.
